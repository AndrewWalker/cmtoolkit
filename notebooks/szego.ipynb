# %%
# %matplotlib inline
import sys; sys.path.append('..')
import matplotlib.pyplot as plt
import numpy as np

from conformalmapping import *

# %%
G = Splinep.from_complex_list([ 
    0.2398 + 0.6023j, 0.3567 + 1.0819j, 0.2632 + 1.5965j,
    -0.5205 + 1.7485j, -1.0585 + 1.1170j, -1.0702 + 0.5088j,
    -0.5906 + 0.0994j, -0.7778 - 0.4269j, -1.2924 - 0.6140j,
    -1.4561 - 1.2456j, -0.5439 - 1.3509j, 0.2515 - 1.0702j,
    0.3099 - 0.6023j, 0.7427 - 0.5906j, 1.1053 - 0.1813j,
    1.2807 + 0.3567j 
])

# %%
S = Szego(G, 0)

# %%
t = np.arange(20)/20.

plt.subplot(1,2,1)
G.plot()
zs = G(t)
plt.plot(zs.real, zs.imag, 'r.')

plt.subplot(1,2,2)
Circle(0, 1).plot()
zs = np.exp(1.0j * S.theta(t))
print zs.shape
plt.plot(zs.real, zs.imag, 'r.')
# Out:
# (20, 20)
# [<matplotlib.lines.Line2D at 0x108dfd650>,
#  <matplotlib.lines.Line2D at 0x108dfdf10>,
#  <matplotlib.lines.Line2D at 0x108e240d0>,
#  <matplotlib.lines.Line2D at 0x108e24250>,
#  <matplotlib.lines.Line2D at 0x108e243d0>,
#  <matplotlib.lines.Line2D at 0x108e24550>,
#  <matplotlib.lines.Line2D at 0x108e246d0>,
#  <matplotlib.lines.Line2D at 0x108e24850>,
#  <matplotlib.lines.Line2D at 0x108e249d0>,
#  <matplotlib.lines.Line2D at 0x108e24b50>,
#  <matplotlib.lines.Line2D at 0x108e24cd0>,
#  <matplotlib.lines.Line2D at 0x108e24e50>,
#  <matplotlib.lines.Line2D at 0x108e24fd0>,
#  <matplotlib.lines.Line2D at 0x108e0a190>,
#  <matplotlib.lines.Line2D at 0x108e0a310>,
#  <matplotlib.lines.Line2D at 0x108e0a490>,
#  <matplotlib.lines.Line2D at 0x108e0a610>,
#  <matplotlib.lines.Line2D at 0x108e0a790>,
#  <matplotlib.lines.Line2D at 0x108e0a910>,
#  <matplotlib.lines.Line2D at 0x108e0aa90>]
